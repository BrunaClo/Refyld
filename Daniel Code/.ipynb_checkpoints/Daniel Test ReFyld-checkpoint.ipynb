# %%
import pandas as pd
import os

# %%
#read_file=pd.read_excel(r'C:\Users\Danie\OneDrive\Email attachments\Refyld-Ensembles-de-publicités-1-mar-2021-29-mar-2021.xlsx')
#read_file.to_csv (r'C:\Users\Danie\OneDrive\Email attachments\Refyld-Ensembles-de-publicités-1-mar-2021-29-mar-2021.csv')

# %%
#df_pub=pd.read_csv(r'C:\Users\Danie\OneDrive\Email attachments\Refyld-Ensembles-de-publicités-1-mar-2021-29-mar-2021.csv')

# %%
##read_file=pd.read_excel(r'C:\Users\Danie\OneDrive\Email attachments\Rapport-sans-titre-Feb-15-2021-Mar-29-2021.xlsx')
#read_file.to_csv (r'C:\Users\Danie\OneDrive\Email attachments\Rapport-sans-titre-Feb-15-2021-Mar-29-2021##.csv')

# %%
#df_pub_C=pd.read_csv(r'C:\Users\Danie\OneDrive\Email attachments\Rapport-sans-titre-Feb-15-2021-Mar-29-2021.csv')#

# %%
#pd.read_csv(r'C:\Users\Danie\Downloads\Detailed_Post_Performance_26-12-2020_to_26-03-2021.CSV')

# %%
#pd.read_excel(r'C:\Users\Danie\Downloads\Audience.xls', encoding='utf32')

# %%
#pd.read_csv(r'C:\Users\Danie\Downloads\survey_export_Votre_avis_sur_la_page_d_accueil_du_site_Refyld__Mar_26_2021.csv')

# %%
#pd.read_csv(r'C:\Users\Danie\Downloads\campaign_Campaign_Single_Welcome_Email_Mar_26_2021.csv', error_bad_lines=False)

# %%
#pd.read_csv(r'C:\Users\Danie\Downloads\campaign_Campaign_5_Documentaires_Pour_S_Inspirer__Mar_26_2021.csv', error_bad_lines=False)

# %%
#pd.read_csv(r'C:\Users\Danie\Downloads\campaign_Campaign_Hello_De_La_Team_Refyld__Mar_26_2021.csv', error_bad_lines=False)

# %%
#pd.read_excel(r'C:\Users\Danie\Downloads\Contenu_(1).xls')

# %%
#pd.read_csv(r'C:\Users\Danie\Downloads\data-export (3).csv', error_bad_lines=False)

# %%
#pd.read_csv(r'C:\Users\Danie\Downloads\data-export (2).csv', error_bad_lines=False, header=8)

# %%
df = pd.read_csv(r'C:\Users\Danie\Downloads\Data Complet.csv', sep=';')

# %%
df.head()
# Out:
#     Prénom            Nom       Prénom - Nom  Sexe  Age  \
# 0    romain         romain    romain-fontanel    H  NaN
# 1    Élodie          Ramel       elodie-ramel    F  NaN
# 2      Amel        Ahmedou          melacafez    F  NaN
# 3     Elina  Le Gourvellec  elinalegourvellec    F  NaN
# 4  PHILIPPE          BIGOT          phmabigot    H  NaN
#
#    Situation Familliale   Profession                       Adresse   \
# 0                    NaN         NaN              10 place franklin
# 1                    NaN         NaN       23 Avenue Albert Laurens
# 2                    NaN         NaN     5 Allée Alexandre Vialatte
# 3                    NaN         NaN          16 Avenue de l'Alcyon
# 4                    NaN         NaN  8 Impasse du Chemin de Gesnes
#
#   Complement Adresse Code postal                     Ville            Région   \
# 0                NaN        68100                  Mulhouse         Grand-Est
# 1                NaN        34230            Saint-Pargoire         Occitanie
# 2        c/o Labadie        75013  Paris 13e Arrondissement     Île-de-France
# 3                NaN        44300                    Nantes  Pays-de-la-Loire
# 4                NaN        61000  Saint-Germain-du-Corbéis         Normandie
#
#   Pays   Nom d'utilisateur  Identifiant de la contrepartie  \
# 0    FR    romain-fontanel                        655971.0
# 1    FR       elodie-ramel                        655971.0
# 2    FR          melacafez                        656196.0
# 3    FR  elinalegourvellec                        655971.0
# 4    FR          phmabigot                        655971.0
#
#                      Courriel Numéro de téléphone  \
# 0  romain.fontanel@hotmail.fr        +33671350519
# 1    elodie.ramel@outlook.com       +330622676348
# 2          melacafez@yahoo.fr       +330622242230
# 3  elinalegourvellec@yahoo.fr        +33683876077
# 4          phmabigot@yahoo.fr       +330601843644
#
#         Titre de la contrepartie  Quantité  Montant unitaire total
# 0  Adhésion à vie - Tarif réduit       1.0                    39.0
# 1  Adhésion à vie - Tarif réduit       1.0                    39.0
# 2           ADHÉSION À VIE - Duo       1.0                    99.0
# 3  Adhésion à vie - Tarif réduit       1.0                    39.0
# 4  Adhésion à vie - Tarif réduit       1.0                    39.0

# %%
df.shape
# Out:
# (1195, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1195 entries, 0 to 1194
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Prénom                          1157 non-null   object
#  1   Nom                             1157 non-null   object
#  2   Prénom - Nom                    1167 non-null   object
#  3   Sexe                            1154 non-null   object
#  4   Age                             0 non-null      float64
#  5   Situation Familliale            0 non-null      float64
#  6   Profession                      0 non-null      float64
#  7   Adresse                         1160 non-null   object
#  8   Complement Adresse              223 non-null    object
#  9   Code postal                     1160 non-null   object
#  10  Ville                           1160 non-null   object
#  11  Région                          866 non-null    object
#  12  Pays                            1185 non-null   object
#  13  Nom d'utilisateur               1167 non-null   object
#  14  Identifiant de la contrepartie  1156 non-null   float64
#  15  Courriel                        1167 non-null   object
#  16  Numéro de téléphone             1160 non-null   object
#  17  Titre de la contrepartie        1156 non-null   object
#  18  Quantité                        1167 non-null   float64
#  19  Montant unitaire total          1167 non-null   float64
# dtypes: float64(6), object(14)
# memory usage: 186.8+ KB

# %%
df.columns
# Out:
# Index(['Prénom ', 'Nom ', 'Prénom - Nom ', 'Sexe', 'Age',
#        'Situation Familliale ', 'Profession', 'Adresse ', 'Complement Adresse',
#        'Code postal ', 'Ville ', 'Région ', 'Pays ', 'Nom d'utilisateur',
#        'Identifiant de la contrepartie', 'Courriel', 'Numéro de téléphone',
#        'Titre de la contrepartie', 'Quantité', 'Montant unitaire total'],
#       dtype='object')

# %%
df['Profession'].value_counts()
# Out:
# Series([], Name: Profession, dtype: int64)

# %%
df['Titre de la contrepartie'].value_counts()
# Out:
# Adhésion à vie - Tarif réduit                 987
# ADHÉSION À VIE 🤩                               98
# ADHÉSION À VIE - Prix réduit                   36
# ADHÉSION À VIE - Duo                           18
# Adhésion à vie - Tarif normal                  12
# ADHÉSION À VIE - Share the love !               2
# ADHÉSION À VIE  À -35% 🥳 Prix de lancement      1
# ADHÉSION À VIE - Prix normal                    1
# ADHÉSION À VIE - Trio                           1
# Name: Titre de la contrepartie, dtype: int64

# %%
df['Ville '].value_counts()
# Out:
# Paris                       49
# Paris 11e Arrondissement    25
# Paris 18e Arrondissement    17
# Toulouse                    16
# Paris 12e Arrondissement    16
#                             ..
# Féternes                     1
# Ermont                       1
# Biarritz                     1
# Bagneux                      1
# Sète                         1
# Name: Ville , Length: 711, dtype: int64

# %%
df.Sexe.value_counts()
# Out:
# F    922
# H    232
# Name: Sexe, dtype: int64

# %%
round(df.isna().sum()/df.shape[0]*100, 2)
# Out:
# Prénom                              3.18
# Nom                                 3.18
# Prénom - Nom                        2.34
# Sexe                                3.43
# Age                               100.00
# Situation Familliale              100.00
# Profession                        100.00
# Adresse                             2.93
# Complement Adresse                 81.34
# Code postal                         2.93
# Ville                               2.93
# Région                             27.53
# Pays                                0.84
# Nom d'utilisateur                   2.34
# Identifiant de la contrepartie      3.26
# Courriel                            2.34
# Numéro de téléphone                 2.93
# Titre de la contrepartie            3.26
# Quantité                            2.34
# Montant unitaire total              2.34
# dtype: float64

# %%
df['Région '].value_counts().head(20)
# Out:
# Île-de-France                                                    299
# Auvergne-Rhône-Alpes                                             160
# Nouvelle-Aquitaine                                                64
# Occitanie                                                         62
# Provence-Alpes-Côte d'Azur                                        42
# Pays-de-la-Loire                                                  35
# Grand-Est                                                         34
# Bretagne                                                          22
# Centre-Val de Loire                                               19
# Hauts-de-France                                                   17
# Bourgogne-Franche-Comté                                           15
# Normandie                                                         14
# France                                                            10
# Région de Bruxelles-Capitale - Brussels Hoofdstedelijk Gewest      5
# FRANCE                                                             5
# Genève                                                             5
# Vaud                                                               4
# Paris                                                              3
# Haute-Savoie                                                       3
# Noord-Holland                                                      2
# Name: Région , dtype: int64

# %%
df.Quantité.value_counts()
# Out:
# 1.0    1131
# 2.0      24
# 3.0       8
# 4.0       2
# 5.0       2
# Name: Quantité, dtype: int64

# %%
df['Identifiant de la contrepartie'].value_counts()
# Out:
# 655971.0    987
# 669620.0     98
# 663095.0     36
# 656196.0     12
# 657937.0     12
# 669624.0      6
# 656199.0      2
# 663097.0      1
# 656197.0      1
# 656194.0      1
# Name: Identifiant de la contrepartie, dtype: int64

# %%
df['Titre de la contrepartie'].value_counts()
# Out:
# Adhésion à vie - Tarif réduit                 987
# ADHÉSION À VIE 🤩                               98
# ADHÉSION À VIE - Prix réduit                   36
# ADHÉSION À VIE - Duo                           18
# Adhésion à vie - Tarif normal                  12
# ADHÉSION À VIE - Share the love !               2
# ADHÉSION À VIE  À -35% 🥳 Prix de lancement      1
# ADHÉSION À VIE - Prix normal                    1
# ADHÉSION À VIE - Trio                           1
# Name: Titre de la contrepartie, dtype: int64

# %%
df['Code postal '].value_counts().head(20)
# Out:
# 75011    32
# 75018    27
# 75015    23
# 75017    21
# 07100    19
# 75013    17
# 75012    16
# 75020    12
# 75010    10
# 75019     9
# 07430     9
# 75009     9
# 75016     8
# 69002     8
# 69007     7
# 75007     7
# 44000     7
# 92500     6
# 75014     6
# 69003     6
# Name: Code postal , dtype: int64

# %%
df1['Pays '].value_counts()
# Out:
# FR    1123
# CH      14
# BE       9
# DE       5
# NL       2
# RE       2
# GF       1
# IE       1
# GB       1
# PT       1
# DK       1
# Name: Pays , dtype: int64

# %%
df1=df.copy()

# %%
df1.drop(['Age','Situation Familliale ', 'Profession','Prénom - Nom ', 'Numéro de téléphone', 'Courriel'],axis=1, inplace=True)

# %%
df1.isnull().sum()
# Out:
# Prénom                             38
# Nom                                38
# Sexe                               41
# Adresse                            35
# Complement Adresse                972
# Code postal                        35
# Ville                              35
# Région                            329
# Pays                               10
# Nom d'utilisateur                  28
# Identifiant de la contrepartie     39
# Titre de la contrepartie           39
# Quantité                           28
# Montant unitaire total             28
# dtype: int64

# %%
df1['Prénom '].unique()
# Out:
# array(['romain', 'Élodie', 'Amel', 'Elina', 'PHILIPPE', 'Maïder',
#        'Vincent', 'Charlotte', 'Jean-Christophe', 'Selvanie', 'Alexandre',
#        'Elisabeth', 'Laetitia', 'Emma', 'Sandrine', 'Patricia', 'Julien',
#        'Cyril', 'Jérémy', 'Marc', 'Hélène', 'sandrine', 'Dorothée',
#        'Aurore', 'Jessica', 'Dominique', 'Eve', 'Sandie', 'Léonie',
#        'Romain', 'Apolline', 'HELENE', 'Regine', 'sophie', 'Patrizia',
#        'Darlene', 'benedicte', 'florence', 'Charline', 'Véronique',
#        'Kevin', 'Carole', 'Joséphine', 'Julie', 'Monique', 'SABINE',
#        'Emmanuelle', 'Amandine', 'Denis', 'Gauthier', 'Anne', 'Sid-Ahmed',
#        'Penélope', 'Marie-Christine', 'Marion', 'Éléonore', 'Audrey',
#        'Gaëlle', 'NATHALIE', 'Anne-Sophie', 'Veronique', 'Cendrine',
#        'Valérie', 'Anabelle', 'Emmanuel', 'Camille', 'Sarah', 'Sebastien',
#        'Pierre', 'Manuella', 'valérie', 'Béatrice', 'Marine', 'Claire',
#        'Martine', 'Safia', 'Ophelie', 'Caroline', 'Christine',
#        'Catherine', 'Nathalie', 'Daniel', 'Isabelle', 'estefania', 'M',
#        'Laura', 'Antoine', 'Sandra', 'JEAN-LOUIS', 'Yohanne', 'Eva',
#        'Céline', 'Noemie', 'Sophie', 'Anne Sophie', 'GREGORY',
#        'Christian', 'Evelyne', nan, 'Francis', 'Magali', 'Olivier',
#        'Amélie', 'alexandre', 'Pascal', 'Philippe', 'Yves', 'MARC',
#        'Cassandre', 'Beatrice', 'Axelle', 'Lydie', 'Marie', 'Mathilde',
#        'Chloé', 'BENJAMIN', 'Ludivine', 'Patrick', 'Saskia', 'Jennifer',
#        'Elody', 'Floriane', 'Rym', 'Corinne', 'Jérôme', 'Joanna',
#        'Matthieu', 'Nicolas', 'Pamela', 'Manon', 'Pauline',
#        'Marie-Noëlle', 'Eléonore', 'Florian', 'Johanna', 'Amelie',
#        'Christelle', 'Prescillia', 'Anais', 'Eden', 'Oussama', 'Lucie',
#        'Virginie', 'Guillaume', 'maele', 'Luana', 'FANNY', 'Bastien',
#        'Milena', 'François', 'Julia', 'veronique', 'Yannick', 'VIRGINIE',
#        'Clélie', 'Maxime', 'Victoire', 'Marianne', 'Florence', 'Myriam',
#        'Alma', 'Stéphanie', 'Valentine', 'Geraldine', 'Louis', 'Alice',
#        'ISABELLE', 'Océane', 'Marie-Neige', 'Euriel', 'Doria', 'Erell',
#        'Laurent', 'Bénédicte', 'Celine', 'Jonathan', 'Natalia', 'Gwënn',
#        'Ophélie', 'Sylvie', 'Capucine', 'Lucas', 'Guilaume', 'Hillel',
#        'nathalie', 'Sullivan', 'Eric', 'Claude', 'Alexandra', 'Cécile',
#        'Laure', 'Maylis', 'Esther', 'caroline', 'Anne Laure', 'Charlene',
#        'Coralie', 'Pascale', 'Mélanie', 'Alix', 'Cannelle', 'Fanny',
#        'Paula', 'Bérénice', 'Sélia', 'Lea', 'Johanne', 'Baptiste',
#        'Clément', 'charlyne', 'Olga & Cyril', 'Lies & Patrick',
#        'Aurélie & Renaud', 'Laurie', 'katleen', 'Eliane', 'martine',
#        'Elise', 'Marie-Luce', 'Maïlys', 'Sybille', 'Arnaud', 'Eugénie',
#        'Lionel', 'Héléna', 'jérémy', 'Laëtitia', 'DAMIEN', 'Karine',
#        'guillaume', 'Noëmie', 'famille', 'Nahid', 'Fanny-Laure',
#        'abdessalem', 'Leslie', 'Laurence', 'Célia', 'julie', 'Diana',
#        'Tara', 'Lucile', 'jb', 'justine', 'Ingrid', 'Salomé', 'Brice',
#        'claire', 'Angela', 'Siriane', 'Anaïs', 'Quentin', 'Mélissa',
#        'Aurélien', 'Dimitri', 'Anne-Lise', 'Adriane', 'Aude', 'Carla',
#        'Josephine', 'Houda', 'Loryn', 'Erwan', 'marie et dimitri',
#        'Elyse', 'Candice', 'pierre', 'Aurélie', 'Virgile', 'Damien',
#        'Marilyse', 'Maxence', 'Alexia', 'Martial', 'Anna', 'fabienne',
#        'Norma', 'Amanda', 'Perrine', 'Galaad', 'Philomène', 'Aline',
#        'Pía', 'Isabel', 'Laury', 'Elodie', 'SANDRINE', 'Hyun-Jung',
#        'Loïc', 'Melanie', 'Chris', 'Thibault', 'Clermont', 'S et T',
#        'Romane', 'Léa', 'Mélina', 'Katharina', 'Flore', 'Victoria',
#        'Eléa', 'Aymeric', 'Florent', 'Justine', 'Jean-Paul', 'Nehla',
#        'Teddy', 'Claire-Lise', 'Déborah', 'Thomas', 'Viviane', 'Aishat',
#        'Ying-Ying', 'Samantha', 'Agathe', 'Sabrina', 'emilie', 'Clemence',
#        'Louise', 'Berengere', 'Maud', 'Juliette', 'Laurianne', 'Rose',
#        'marina', 'Roselyne', 'Phuoc', 'GENDRON', 'Logan', 'Charlène',
#        'Faustine', 'Mona', 'William', 'Anouck', 'Radiance', 'Gwenn',
#        'Gaelle', 'lorene', 'Clara', 'Paul-Henry', 'Clémence',
#        'Anne Ségolene', 'daphne', 'EMILIE ET HUGUES', 'Joëlle', 'CELINE',
#        'Cora-Lynn', 'Lise', 'Cathydja', 'Diane', 'valerie', 'Grégory',
#        'Alizee', 'Anastasiia', 'remy', 'Anastasia', 'Ivan', 'Françoise',
#        'lydie', 'Thirsa', 'Emilie', 'PATRICIA', 'laurent', 'Simon',
#        'Margaux', 'Karin', 'Aurelie', 'Mailys', 'Hanen', 'Juliet',
#        'CHRISTELLE', 'Annick', 'Soizic', 'Valerie', 'Gollnhofer',
#        'Géraldine', 'Ghislaine', 'Charles', 'OLIVIA', 'Azza', 'katell',
#        'Tiara', 'Séverine', 'Dany', 'philippine', 'Paddy', 'odile',
#        'Florie', 'Frere', 'Loise', 'Graziella', 'Lena', 'Vanina', 'Inès',
#        'Thierry', 'Estelle', 'Andréa', 'Chloe', 'Gabrielle', 'Danielle',
#        'Lauriana', 'Delphine', 'Angelina', 'Lauriane', 'Audric', 'Martin',
#        'sandra', 'Aurelien', 'alexandra', 'Sara', 'Henri', 'Satsuky',
#        'Paola', 'Yann', 'Denis R', 'Geoffrey', 'Bathiste', 'Angèle',
#        'Barbara', 'Xuan', 'Cristel', 'Romeo', 'Nadine', 'Isabeau',
#        'Khadija', 'marthe', 'Marta', 'Emanuelle', 'Valentin', 'Morgane',
#        'Claudia', 'LACHAUME', 'Rosine', 'Chrystal', 'Aurélia', 'Noemi',
#        'Tim', 'Solange', 'Ondine', 'Didier', 'Olivia', 'David', 'Ludovic',
#        'Cecile', 'MARIE', 'Yvette', 'MELANIE', 'chantal', 'RENAUD',
#        'Juliane', 'Amalya', 'SIMON', 'Gwenaelle', 'Hugues', 'Sebastian',
#        'evelyne', 'Bernard', 'Maeva', 'Robin', 'Marinette', 'Mathieu',
#        'Anthony', 'Gilbert', 'Eryn', 'VALERIE', 'marie', 'Anne lise',
#        'Corine', 'ERIC', 'delphine', 'Michael', 'MAUD', 'Eloise',
#        'Victor', 'Mélie', 'Christophe', 'Lorée', 'Marie Gabrielle',
#        'Clémentine', 'Linh', 'JULIEN', 'Anatole', 'Clarisse', 'Gabriel',
#        'aline', 'Marius', 'Aïni', 'Jimmy', 'Tiphaine', 'Frederic',
#        'Barthélemy', 'Ariane', 'Frédéric', 'Nessa', 'Gaëtan',
#        'Anne-Marie', 'mathieu', 'PAUL', 'Marie-Pierre', 'Margot',
#        'Maurane', 'Maryne', 'Hilda', 'Heïdi', 'Roxanne', 'Astrid',
#        'thomas', 'Emeline', 'Florine', 'Benjamin', 'Vivien', 'Elsa',
#        'Prune', 'Sophia', 'Zoe', 'Gabriella', 'Cyndie', 'Florentine',
#        'Nassim', 'MARIELLE', 'Sabine', 'Hanna', 'Enaelle', 'Rachel',
#        'Killian', 'Thibaud', 'mickael', 'Wassima', 'Pascaline', 'Héloïse',
#        'Felix', 'Marie Cécile', 'Tatiana', 'Guillemette', 'Maëva', 'Lola',
#        'Natacha', 'Adèle', 'Remy', 'Ella', 'Jean-Luc', 'Fabienne',
#        'Anne-Charlotte', 'Helena', 'val', 'Patryk', 'Alicia', 'Hugo',
#        'DIANE', 'garance', 'Adrien', 'Rouba', 'Sidonie', 'LEVRAT',
#        'Matthias', 'Nelly', 'Kelly', 'Anne-Emmanuelle', 'Vina', 'Youna',
#        'Annika', 'Sakina', 'Léopold', 'Adriana', 'Kristina', 'Thiara',
#        'COLUCCI', 'Frédérique', 'Patrice', 'Melodie', 'Nidavan',
#        'Marie-Laure', 'Stéphany', 'Marie-Anne', 'Batiste', 'pauline',
#        'Odeline', 'Orane', 'Lorna', 'Huguette', 'Maëla', 'Pierre-xavier',
#        'Kary', 'Bertille', 'James', 'Nour', 'Allan', 'Natalie', 'Ilfynn',
#        'Maniline', 'Théodora', 'Maya', 'Jamie', 'Marina'], dtype=object)

# %%
lst_to_drop=df1[df1['Quantité'].isna()].index

# %%
df1.drop(lst_to_drop, inplace=True)

# %%
df1[df1['Pays ']=='RE']
# Out:
#      Prénom        Nom  Sexe             Adresse  Complement Adresse  \
# 541     remy   exelmans  NaN   33 ter allée cocos                NaN
# 944  Mélanie  Tuffereau    F  2 rue tétin savigny                NaN
#
#     Code postal                 Ville   Région  Pays  Nom d'utilisateur  \
# 541        97438             Ste Marie  Reunion    RE         rexelmans
# 944        97427  Étang salé les bains      NaN    RE        melanituff
#
#      Identifiant de la contrepartie       Titre de la contrepartie  Quantité  \
# 541                        655971.0  Adhésion à vie - Tarif réduit       1.0
# 944                        655971.0  Adhésion à vie - Tarif réduit       1.0
#
#      Montant unitaire total
# 541                    39.0
# 944                    39.0

# %%
df1[df1['Sexe'].isna()]
# Out:
#          Prénom             Nom  Sexe                    Adresse   \
# 183          NaN             NaN  NaN          5, rue de charonne
# 541         remy        exelmans  NaN          33 ter allée cocos
# 686      Satsuky          Urbain  NaN  Avenue Isidore Geyskens 98
# 794        Marie         Quement  NaN            32 Rue de Brazza
# 838     Matthieu        Bienfait  NaN     255 Boulevard Bazeilles
# 846          NaN             NaN  NaN                         NaN
# 861        Mélie    POUSTAY-LING  NaN  3 Allée du Bois des Chênes
# 863   Christophe           Dvisé  NaN             Elegemstraat 57
# 985          NaN             NaN  NaN                         NaN
# 1043    Jean-Luc      Planchenot  NaN            4 Rue de Diarupt
# 1056         val         AGUNAOU  NaN   65 Avenue de Rochetaillée
# 1058      Marine  Pannaud Deniau  NaN         31 rue de bourgogne
# 1139    Caroline           Panel  NaN       48 Chemin du Ruisseau
#
#      Complement Adresse Code postal          Ville   \
# 183                 NaN        75011          Paris
# 541                 NaN        97438      Ste Marie
# 686                 NaN         1160      Auderghem
# 794                 NaN        92800        Puteaux
# 838                 NaN        83000         Toulon
# 846                 NaN          NaN            NaN
# 861                 NaN        94370   Sucy-en-Brie
# 863                 NaN         1700        Dilbeek
# 985                 NaN          NaN            NaN
# 1043                NaN        88520      Wisembach
# 1056        le Montréal        42100  Saint-Étienne
# 1058                NaN        75007          Paris
# 1139                NaN        42520         Roisey
#
#                                                 Région  Pays   \
# 183                                                 NaN    FR
# 541                                             Reunion    RE
# 686   Région de Bruxelles-Capitale - Brussels Hoofds...    BE
# 794                                       Île-de-France    FR
# 838                          Provence-Alpes-Côte d'Azur    FR
# 846                                                 NaN   NaN
# 861                                       Île-de-France    FR
# 863                                          Vlaanderen    BE
# 985                                                 NaN   NaN
# 1043                                          Grand-Est    FR
# 1056                               Auvergne-Rhône-Alpes    FR
# 1058                                 Nouvelle-Aquitaine    FR
# 1139                               Auvergne-Rhône-Alpes    FR
#
#       Nom d'utilisateur  Identifiant de la contrepartie  \
# 183          k-mayalevy                        655971.0
# 541           rexelmans                        655971.0
# 686            tsutsu22                        655971.0
# 794           quement-m                        655971.0
# 838   matthieu-bienfait                             NaN
# 846            cdarblet                             NaN
# 861           melicorne                        655971.0
# 863   christophe-devise                             NaN
# 985             erzbeth                        655971.0
# 1043         planchenot                             NaN
# 1056          fifival-0                        663095.0
# 1058     marine-pannaud                        663095.0
# 1139     panel-caroline                             NaN
#
#            Titre de la contrepartie  Quantité  Montant unitaire total
# 183   Adhésion à vie - Tarif réduit       1.0                    39.0
# 541   Adhésion à vie - Tarif réduit       1.0                    39.0
# 686   Adhésion à vie - Tarif réduit       1.0                    39.0
# 794   Adhésion à vie - Tarif réduit       1.0                    39.0
# 838                             NaN       1.0                    11.0
# 846                             NaN       1.0                     1.0
# 861   Adhésion à vie - Tarif réduit       1.0                    39.0
# 863                             NaN       1.0                    11.0
# 985   Adhésion à vie - Tarif réduit       1.0                    39.0
# 1043                            NaN       1.0                     1.0
# 1056   ADHÉSION À VIE - Prix réduit       1.0                    49.0
# 1058   ADHÉSION À VIE - Prix réduit       1.0                    49.0
# 1139                            NaN       1.0                    11.0

# %%
df1[df1['Identifiant de la contrepartie'].isna()]
# Out:
#          Prénom         Nom  Sexe                         Adresse   \
# 84     Christine       Mabit    F  3 impasse des Hauts du ruisseau
# 734          NaN         NaN    F                              NaN
# 806          NaN         NaN    F                              NaN
# 816     Nathalie     BASTIEN    F                          Penvern
# 826          NaN         NaN    F                              NaN
# 838     Matthieu    Bienfait  NaN          255 Boulevard Bazeilles
# 846          NaN         NaN  NaN                              NaN
# 863   Christophe       Dvisé  NaN                  Elegemstraat 57
# 920          NaN         NaN    H                              NaN
# 1043    Jean-Luc  Planchenot  NaN                 4 Rue de Diarupt
# 1139    Caroline       Panel  NaN            48 Chemin du Ruisseau
#
#      Complement Adresse Code postal       Ville                      Région   \
# 84                  NaN        31570       Lanta                         NaN
# 734                 NaN          NaN         NaN                         NaN
# 806                 NaN          NaN         NaN                         NaN
# 816                 NaN        56540  Le Croisty                    Bretagne
# 826                 NaN          NaN         NaN                         NaN
# 838                 NaN        83000      Toulon  Provence-Alpes-Côte d'Azur
# 846                 NaN          NaN         NaN                         NaN
# 863                 NaN         1700     Dilbeek                  Vlaanderen
# 920                 NaN          NaN         NaN                         NaN
# 1043                NaN        88520   Wisembach                   Grand-Est
# 1139                NaN        42520      Roisey        Auvergne-Rhône-Alpes
#
#      Pays   Nom d'utilisateur  Identifiant de la contrepartie  \
# 84      FR     caroline-mabit                             NaN
# 734    NaN    madelinecollard                             NaN
# 806    NaN           vtoletti                             NaN
# 816     FR          nabastien                             NaN
# 826    NaN    roxane-makpopan                             NaN
# 838     FR  matthieu-bienfait                             NaN
# 846    NaN           cdarblet                             NaN
# 863     BE  christophe-devise                             NaN
# 920    NaN           jdozance                             NaN
# 1043    FR         planchenot                             NaN
# 1139    FR     panel-caroline                             NaN
#
#      Titre de la contrepartie  Quantité  Montant unitaire total
# 84                        NaN       1.0                     1.0
# 734                       NaN       1.0                    15.0
# 806                       NaN       1.0                     1.0
# 816                       NaN       1.0                     6.0
# 826                       NaN       1.0                    25.0
# 838                       NaN       1.0                    11.0
# 846                       NaN       1.0                     1.0
# 863                       NaN       1.0                    11.0
# 920                       NaN       1.0                    50.0
# 1043                      NaN       1.0                     1.0
# 1139                      NaN       1.0                    11.0

# %%
df1['Quantité'].value_counts(normalize=True)*100
# Out:
# 1.0    96.915167
# 2.0     2.056555
# 3.0     0.685518
# 4.0     0.171380
# 5.0     0.171380
# Name: Quantité, dtype: float64

# %%
df1.groupby('Montant unitaire total')['Quantité'].value_counts().to_frame()
# Out:
#                                  Quantité
# Montant unitaire total Quantité
# 1.0                    1.0              4
# 6.0                    1.0              1
# 11.0                   1.0              3
# 15.0                   1.0              1
# 25.0                   1.0              1
# 39.0                   1.0           1049
# 49.0                   1.0             37
# 50.0                   1.0              1
# 78.0                   2.0             24
#                        1.0              6
# 79.0                   1.0             13
# 99.0                   1.0             12
# 117.0                  3.0              8
# 149.0                  1.0              1
# 156.0                  4.0              2
# 195.0                  5.0              2
# 349.0                  1.0              2

# %%
df1.columns
# Out:
# Index(['Prénom ', 'Nom ', 'Sexe', 'Adresse ', 'Complement Adresse',
#        'Code postal ', 'Ville ', 'Région ', 'Pays ', 'Nom d'utilisateur',
#        'Identifiant de la contrepartie', 'Titre de la contrepartie',
#        'Quantité', 'Montant unitaire total'],
#       dtype='object')

# %%
df1[df1.Sexe.isna()]
# Out:
#      Prénom      Nom  Sexe                   Adresse  Complement Adresse  \
# 183      NaN      NaN  NaN         5, rue de charonne                NaN
# 985      NaN      NaN  NaN                        NaN                NaN
# 1056     val  AGUNAOU  NaN  65 Avenue de Rochetaillée        le Montréal
#
#      Code postal          Ville                Région  Pays   \
# 183         75011          Paris                   NaN    FR
# 985           NaN            NaN                   NaN   NaN
# 1056        42100  Saint-Étienne  Auvergne-Rhône-Alpes    FR
#
#      Nom d'utilisateur  Identifiant de la contrepartie  \
# 183         k-mayalevy                        655971.0
# 985            erzbeth                        655971.0
# 1056         fifival-0                        663095.0
#
#            Titre de la contrepartie  Quantité  Montant unitaire total
# 183   Adhésion à vie - Tarif réduit       1.0                    39.0
# 985   Adhésion à vie - Tarif réduit       1.0                    39.0
# 1056   ADHÉSION À VIE - Prix réduit       1.0                    49.0

# %%
df1.loc[541,'Sexe']='H'

# %%
df1.iloc[541]
# Out:
# Prénom                                                     remy
# Nom                                                    exelmans
# Sexe                                                          H
# Adresse                                      33 ter allée cocos
# Complement Adresse                                          NaN
# Code postal                                               97438
# Ville                                                 Ste Marie
# Région                                                  Reunion
# Pays                                                         RE
# Nom d'utilisateur                                     rexelmans
# Identifiant de la contrepartie                           655971
# Titre de la contrepartie          Adhésion à vie - Tarif réduit
# Quantité                                                      1
# Montant unitaire total                                       39
# Name: 541, dtype: object

# %%
df1.loc[686,'Sexe']='F'

# %%
df1.loc[794,'Sexe']='F'

# %%
df1.loc[838,'Sexe']='H'

# %%
df1.loc[861,'Sexe']='F'

# %%
df1.loc[863,'Sexe']='H'

# %%
df1.loc[1043,'Sexe']='H'

# %%
df1.loc[1058,'Sexe']='F'

# %%
df1.loc[1139,'Sexe']='F'

# %%
df1.drop(846, inplace=True)

# %%
df2=df1.copy()

# %%
df2.drop(['Code postal ', "Nom d'utilisateur",'Adresse ', 'Complement Adresse','Prénom ', 'Nom '], axis=1, inplace=True)

# %%
df2[df2['Sexe'].isna()]
# Out:
#      Sexe         Ville                Région  Pays   \
# 183   NaN          Paris                   NaN    FR
# 985   NaN            NaN                   NaN   NaN
# 1056  NaN  Saint-Étienne  Auvergne-Rhône-Alpes    FR
#
#       Identifiant de la contrepartie       Titre de la contrepartie  Quantité  \
# 183                         655971.0  Adhésion à vie - Tarif réduit       1.0
# 985                         655971.0  Adhésion à vie - Tarif réduit       1.0
# 1056                        663095.0   ADHÉSION À VIE - Prix réduit       1.0
#
#       Montant unitaire total
# 183                     39.0
# 985                     39.0
# 1056                    49.0

# %%
df2.shape
# Out:
# (1166, 8)

# %%
pd.get_dummies(df2, columns=['Sexe'])
# Out:
#                         Ville                Région  Pays   \
# 0                     Mulhouse             Grand-Est    FR
# 1               Saint-Pargoire             Occitanie    FR
# 2     Paris 13e Arrondissement         Île-de-France    FR
# 3                       Nantes      Pays-de-la-Loire    FR
# 4     Saint-Germain-du-Corbéis             Normandie    FR
# ...                        ...                   ...   ...
# 1162                   Annonay  Auvergne-Rhône-Alpes    FR
# 1163       Boulieu-lès-Annonay  Auvergne-Rhône-Alpes    FR
# 1164    Lyon 2e Arrondissement  Auvergne-Rhône-Alpes    FR
# 1165                  Doussard  Auvergne-Rhône-Alpes    FR
# 1166            Mont-de-Marsan    Nouvelle-Aquitaine    FR
#
#       Identifiant de la contrepartie       Titre de la contrepartie  Quantité  \
# 0                           655971.0  Adhésion à vie - Tarif réduit       1.0
# 1                           655971.0  Adhésion à vie - Tarif réduit       1.0
# 2                           656196.0           ADHÉSION À VIE - Duo       1.0
# 3                           655971.0  Adhésion à vie - Tarif réduit       1.0
# 4                           655971.0  Adhésion à vie - Tarif réduit       1.0
# ...                              ...                            ...       ...
# 1162                        655971.0  Adhésion à vie - Tarif réduit       1.0
# 1163                        657937.0  Adhésion à vie - Tarif normal       1.0
# 1164                        655971.0  Adhésion à vie - Tarif réduit       1.0
# 1165                        655971.0  Adhésion à vie - Tarif réduit       1.0
# 1166                        655971.0  Adhésion à vie - Tarif réduit       1.0
#
#       Montant unitaire total  Sexe_F  Sexe_H
# 0                       39.0       0       1
# 1                       39.0       1       0
# 2                       99.0       1       0
# 3                       39.0       1       0
# 4                       39.0       0       1
# ...                      ...     ...     ...
# 1162                    39.0       1       0
# 1163                    79.0       1       0
# 1164                    39.0       1       0
# 1165                    39.0       1       0
# 1166                    39.0       1       0
#
# [1166 rows x 9 columns]
