# %%
import pandas as pd
import os

# %%
pd.read_csv(r'C:\Users\Danie\Downloads\Detailed_Post_Performance_26-12-2020_to_26-03-2021.CSV')
# Out:
#                  Time Posted  \
# 0   Mar 26, 2021 10:55:19 AM
# 1   Mar 25, 2021 11:00:57 AM
# 2   Mar 24, 2021 09:00:56 AM
# 3   Mar 23, 2021 07:30:23 AM
# 4   Mar 22, 2021 06:14:48 PM
# ..                       ...
# 70   Jan 1, 2021 10:55:21 AM
# 71  Dec 30, 2020 12:01:33 PM
# 72  Dec 29, 2020 10:50:43 AM
# 73  Dec 28, 2020 09:30:27 AM
# 74  Dec 27, 2020 10:01:06 AM
#
#                                             Image URL  \
# 0   https://lg-image-prod.s3.amazonaws.com/ig-anal...
# 1   https://lg-image-prod.s3.amazonaws.com/ig-anal...
# 2   https://lg-image-prod.s3.amazonaws.com/ig-anal...
# 3   https://lg-image-prod.s3.amazonaws.com/ig-anal...
# 4   https://lg-image-prod.s3.amazonaws.com/ig-anal...
# ..                                                ...
# 70  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 71  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 72  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 73  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 74  https://lg-image-prod.s3.amazonaws.com/ig-anal...
#
#                               Instagram Post  \
# 0   https://www.instagram.com/p/CM4K7UJM5xN/
# 1   https://www.instagram.com/p/CM1mvXmghYZ/
# 2   https://www.instagram.com/p/CMy0M0yMo6Z/
# 3   https://www.instagram.com/p/CMwFE2bANXt/
# 4   https://www.instagram.com/p/CMuqD8Sheao/
# ..                                       ...
# 70  https://www.instagram.com/p/CJf4JVEgCX8/
# 71  https://www.instagram.com/p/CJa2DPJADfH/
# 72  https://www.instagram.com/p/CJYJQrHhWDG/
# 73  https://www.instagram.com/p/CJVbQZhgg90/
# 74  https://www.instagram.com/p/CJS55-cAVv0/
#
#                                               Caption  \
# 0   Le week-end est bientôt là ! 🙌⁠\nQu'avez-vou...
# 1   Choisir de consommer de façon responsable supp...
# 2   Notre petit chouchou : le savon Refyld 💫⁠\n👉 0...
# 3   Live Talk Refyld - Les premiers produits ⁠💫 ⁠\...
# 4   Jeu concours @whitesunshoes x @refyld⁠⁠\n⁠⁠\nL...
# ..                                                ...
# 70  La meilleure façon de commencer l'année ? Pren...
# 71  Pour libérer l'accès à la qualité, chez Refyld...
# 72  Je continue dans ma série de livres inspirants...
# 73  En ce dernier lundi de 2020, nous voulions vou...
# 74  "Refyld, dit-nous, comment fais-tu pour nous p...
#
#    Media Type (Image, Video, Carousel)  Followers Engagement  Likes  Comments  \
# 0                                image       7043      0.64%     43         2
# 1                                image       7030       1.0%     72         0
# 2                                image       7026       1.8%    113        12
# 3                                image       7005       1.1%     78         2
# 4                             carousel       6964       6.2%    238       192
# ..                                 ...        ...        ...    ...       ...
# 70                               image       6422       1.8%    111         4
# 71                               image       6434      0.82%     53         0
# 72                            carousel       6445       2.5%    151         8
# 73                               image       6448       2.0%    125         4
# 74                               image       6451       1.2%     78         0
#
#     Impressions  Reach  Video Views  Saves  Linkin.Bio
# 0           584    568          NaN      0         NaN
# 1          1161   1114          NaN      1         NaN
# 2          1922   1900          NaN      4         NaN
# 3          1985   1885          NaN      1         NaN
# 4          2929   2584          NaN     18         NaN
# ..          ...    ...          ...    ...         ...
# 70         2443   2264          NaN      4         NaN
# 71         1496   1368          NaN      3         NaN
# 72         3473   3023          NaN     53         NaN
# 73         2306   2155          NaN      2         NaN
# 74         2432   2193          NaN     10         NaN
#
# [75 rows x 14 columns]

# %%
pd.read_excel(r'C:\Users\Danie\Downloads\Audience.xls', encoding='utf32')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-28bed2f5c866> in <module>
# ----> 1 pd.read_excel(r'C:\Users\Danie\Downloads\Audience.xls', encoding='utf32')
#
# D:\IronHack\.conda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# TypeError: read_excel() got an unexpected keyword argument 'encoding'

# %%
pd.read_csv(r'C:\Users\Danie\Downloads\survey_export_Votre_avis_sur_la_page_d_accueil_du_site_Refyld__Mar_26_2021.csv')
# Out:
#                    Date  Email  \
# 0   2021-03-04 11:49:52    NaN
# 1   2021-03-04 11:57:26    NaN
# 2   2021-03-04 12:58:54    NaN
# 3   2021-03-04 13:02:33    NaN
# 4   2021-03-04 13:19:16    NaN
# 5   2021-03-04 13:53:17    NaN
# 6   2021-03-04 14:05:05    NaN
# 7   2021-03-04 14:38:57    NaN
# 8   2021-03-04 14:39:30    NaN
# 9   2021-03-04 18:45:47    NaN
# 10  2021-03-08 09:00:20    NaN
# 11  2021-03-14 19:39:53    NaN
# 12  2021-03-16 10:56:48    NaN
# 13  2021-03-22 12:42:43    NaN
#
#     Question 1: Comment trouvez-vous la page d'accueil du site sur une échelle de 0 à 10 ?  \
# 0                                                   8
# 1                                                   7
# 2                                                   5
# 3                                                   9
# 4                                                   8
# 5                                                   9
# 6                                                   9
# 7                                                   8
# 8                                                  10
# 9                                                  10
# 10                                                  8
# 11                                                  6
# 12                                                  9
# 13                                                  4
#
#    Question 2: Vous avez découvert la page depuis un ordinateur ou un mobile ?  \
# 0                                              Mobile
# 1                                              Mobile
# 2                                              Mobile
# 3                                              Mobile
# 4                                          Ordinateur
# 5                                              Mobile
# 6                                              Mobile
# 7                                          Ordinateur
# 8                                          Ordinateur
# 9                                          Ordinateur
# 10                                         Ordinateur
# 11                                         Ordinateur
# 12                                         Ordinateur
# 13                                             Mobile
#
#    Question 3: Avez-vous des retours à nous partager sur cette première version de la page d'accueil ?
# 0                                                 NaN
# 1   Plutôt jolie mais il manque des informations c...
# 2   Il faut pouvoir identifier rapidement le conce...
# 3   La page est sobre, légère, elle ressemble bien...
# 4   Pas grand chose à dire (j'y suis pas resté lon...
# 5                                 Sobre, c'est bien.
# 6                                                 NaN
# 7   '- Joli visuel (mais un peu dommage la brosse ...
# 8         Bravo jolie et efficace, navigation facile.
# 9                                                 NaN
# 10                                                NaN
# 11   je sais qu'il s'agit d'un choix d'utiliser un...
# 12  Je le trouve très claire et cohérente avec l'i...
# 13                                                NaN

# %%
pd.read_csv(r'C:\Users\Danie\Downloads\campaign_Campaign_Single_Welcome_Email_Mar_26_2021.csv', error_bad_lines=False)
# Out:
# b'Skipping line 23: expected 2 fields, saw 3\n'
#                            Email Campaign Report
# Title:                      Single welcome email
# Subject Line:                         No Subject
# Delivery Date/Time:       Fri, Mar 26, 2021 6:59
# Overall Stats                                NaN
# Total Recipients:                            996
# Successful Deliveries:                       994
# Bounces:                                2 (0.2%)
# Times Forwarded:                               0
# Forwarded Opens:                               0
# Recipients Who Opened:               736 (74.0%)
# Total Opens:                               1,771
# Last Open Date:                    3/26/21 11:21
# Recipients Who Clicked:              349 (35.1%)
# Total Clicks:                                  0
# Last Click Date:                     1/1/70 1:00
# Total Unsubs:                                  4
# Total Abuse Complaints:                        0
# Times Liked on Facebook:                       0
# Clicks by URL                                NaN

# %%
pd.read_csv(r'C:\Users\Danie\Downloads\campaign_Campaign_5_Documentaires_Pour_S_Inspirer__Mar_26_2021.csv', error_bad_lines=False)
# Out:
# b'Skipping line 23: expected 2 fields, saw 3\nSkipping line 24: expected 2 fields, saw 3\nSkipping line 25: expected 2 fields, saw 3\nSkipping line 26: expected 2 fields, saw 3\nSkipping line 27: expected 2 fields, saw 3\nSkipping line 28: expected 2 fields, saw 3\n'
#                                       Email Campaign Report
# Title:                     5 documentaires pour s'inspirer
# Subject Line:             6 documentaires pour s'inspirer 🙌
# Delivery Date/Time:                 Thu, Feb 18, 2021 11:47
# Overall Stats                                           NaN
# Total Recipients:                                       762
# Successful Deliveries:                                  760
# Bounces:                                           2 (0.3%)
# Times Forwarded:                                          0
# Forwarded Opens:                                          0
# Recipients Who Opened:                          568 (74.7%)
# Total Opens:                                          1,288
# Last Open Date:                               3/26/21 10:55
# Recipients Who Clicked:                           30 (3.9%)
# Total Clicks:                                            50
# Last Click Date:                              3/24/21 23:04
# Total Unsubs:                                             8
# Total Abuse Complaints:                                   1
# Times Liked on Facebook:                                  0
# Clicks by URL                                           NaN

# %%
pd.read_csv(r'C:\Users\Danie\Downloads\campaign_Campaign_Hello_De_La_Team_Refyld__Mar_26_2021.csv', error_bad_lines=False)
# Out:
# b'Skipping line 23: expected 2 fields, saw 3\nSkipping line 24: expected 2 fields, saw 3\n'
#                               Email Campaign Report
# Title:                    Hello de la team Refyld 👋
# Subject Line:             Hello de la team Refyld 👋
# Delivery Date/Time:          Thu, Feb 4, 2021 11:08
# Overall Stats                                   NaN
# Total Recipients:                               766
# Successful Deliveries:                          761
# Bounces:                                   5 (0.7%)
# Times Forwarded:                                  0
# Forwarded Opens:                                  0
# Recipients Who Opened:                  439 (57.7%)
# Total Opens:                                    868
# Last Open Date:                       3/23/21 14:13
# Recipients Who Clicked:                   29 (3.8%)
# Total Clicks:                                    32
# Last Click Date:                       2/7/21 17:23
# Total Unsubs:                                    42
# Total Abuse Complaints:                           0
# Times Liked on Facebook:                          0
# Clicks by URL                                   NaN

# %%
pd.read_excel(r'C:\Users\Danie\Downloads\Contenu_(1).xls')
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-20-707c715911ef> in <module>
# ----> 1 pd.read_excel(r'C:\Users\Danie\Downloads\Contenu_(1).xls')
#
# D:\IronHack\.conda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# D:\IronHack\.conda\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# D:\IronHack\.conda\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# D:\IronHack\.conda\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# D:\IronHack\.conda\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# D:\IronHack\.conda\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      35             return open_workbook(file_contents=data)
#      36         else:
# ---> 37             return open_workbook(filepath_or_buffer)
#      38
#      39     @property
#
# D:\IronHack\.conda\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     146
#     147     from . import book
# --> 148     bk = book.open_workbook_xls(
#     149         filename=filename,
#     150         logfile=logfile,
#
# D:\IronHack\.conda\lib\site-packages\xlrd\book.py in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#      90         t1 = perf_counter()
#      91         bk.load_time_stage_1 = t1 - t0
# ---> 92         biff_version = bk.getbof(XL_WORKBOOK_GLOBALS)
#      93         if not biff_version:
#      94             raise XLRDError("Can't determine file's BIFF version")
#
# D:\IronHack\.conda\lib\site-packages\xlrd\book.py in getbof(self, rqd_stream)
#    1276             bof_error('Expected BOF record; met end of file')
#    1277         if opcode not in bofcodes:
# -> 1278             bof_error('Expected BOF record; found %r' % self.mem[savpos:savpos+8])
#    1279         length = self.get2bytes()
#    1280         if length == MY_EOF:
#
# D:\IronHack\.conda\lib\site-packages\xlrd\book.py in bof_error(msg)
#    1270
#    1271         def bof_error(msg):
# -> 1272             raise XLRDError('Unsupported format, or corrupt file: ' + msg)
#    1273         savpos = self._position
#    1274         opcode = self.get2bytes()
#
# XLRDError: Unsupported format, or corrupt file: Expected BOF record; found b'\xff\xfes\x00e\x00p\x00'

# %%
pd.read_csv(r'C:\Users\Danie\Downloads\data-export (3).csv', error_bad_lines=False)
# Out:
# b'Skipping line 9: expected 1 fields, saw 6\nSkipping line 10: expected 1 fields, saw 6\nSkipping line 11: expected 1 fields, saw 6\nSkipping line 12: expected 1 fields, saw 6\nSkipping line 13: expected 1 fields, saw 6\nSkipping line 14: expected 1 fields, saw 6\nSkipping line 15: expected 1 fields, saw 6\nSkipping line 16: expected 1 fields, saw 6\nSkipping line 17: expected 1 fields, saw 6\nSkipping line 18: expected 1 fields, saw 6\nSkipping line 19: expected 1 fields, saw 6\nSkipping line 20: expected 1 fields, saw 6\nSkipping line 21: expected 1 fields, saw 6\nSkipping line 22: expected 1 fields, saw 6\nSkipping line 23: expected 1 fields, saw 6\nSkipping line 24: expected 1 fields, saw 6\nSkipping line 25: expected 1 fields, saw 6\nSkipping line 26: expected 1 fields, saw 6\nSkipping line 27: expected 1 fields, saw 6\nSkipping line 28: expected 1 fields, saw 6\nSkipping line 29: expected 1 fields, saw 6\nSkipping line 30: expected 1 fields, saw 6\nSkipping line 31: expected 1 fields, saw 6\nSkipping line 32: expected 1 fields, saw 6\nSkipping line 33: expected 1 fields, saw 6\nSkipping line 34: expected 1 fields, saw 6\nSkipping line 35: expected 1 fields, saw 6\nSkipping line 36: expected 1 fields, saw 6\nSkipping line 37: expected 1 fields, saw 6\nSkipping line 38: expected 1 fields, saw 6\nSkipping line 39: expected 1 fields, saw 6\nSkipping line 43: expected 1 fields, saw 3\nSkipping line 44: expected 1 fields, saw 3\nSkipping line 45: expected 1 fields, saw 3\nSkipping line 46: expected 1 fields, saw 3\nSkipping line 47: expected 1 fields, saw 3\nSkipping line 48: expected 1 fields, saw 3\nSkipping line 49: expected 1 fields, saw 3\nSkipping line 50: expected 1 fields, saw 3\nSkipping line 51: expected 1 fields, saw 3\nSkipping line 52: expected 1 fields, saw 3\nSkipping line 53: expected 1 fields, saw 3\nSkipping line 59: expected 1 fields, saw 10\nSkipping line 60: expected 1 fields, saw 10\nSkipping line 61: expected 1 fields, saw 10\nSkipping line 62: expected 1 fields, saw 10\nSkipping line 63: expected 1 fields, saw 10\nSkipping line 64: expected 1 fields, saw 10\nSkipping line 65: expected 1 fields, saw 10\nSkipping line 66: expected 1 fields, saw 10\nSkipping line 67: expected 1 fields, saw 10\nSkipping line 68: expected 1 fields, saw 10\nSkipping line 69: expected 1 fields, saw 10\n'
#     # ----------------------------------------
# 0       # Exportation de rapport au format CSV
# 1                            # Compte : Refyld
# 2                         # Propriété : Refyld
# 3   # ----------------------------------------
# 4                                           #
# 5                   # Date de début : 20210225
# 6                     # Date de fin : 20210326
# 7                   # Date de début : 20210225
# 8                     # Date de fin : 20210326
# 9                      # Tous les utilisateurs
# 10                  # Date de début : 20210225
# 11                    # Date de fin : 20210326

# %%
pd.read_csv(r'C:\Users\Danie\Downloads\data-export (2).csv', error_bad_lines=False, header=8)
# Out:
#      Jour Utilisateurs
# 0    0000            0
# 1    0001           12
# 2    0002           18
# 3    0003           27
# 4    0004           45
# ..    ...          ...
# 201  0115            0
# 202  0116            0
# 203  0117            0
# 204  0118            0
# 205  0119            0
#
# [206 rows x 2 columns]

# %%
df = pd.read_csv(r'C:\Users\Danie\Downloads\Data Complet.csv', sep=';')

# %%
df.head()
# Out:
#     Prénom            Nom       Prénom - Nom  Sexe  Age  \
# 0    romain         romain    romain-fontanel    H  NaN
# 1    Élodie          Ramel       elodie-ramel    F  NaN
# 2      Amel        Ahmedou          melacafez    F  NaN
# 3     Elina  Le Gourvellec  elinalegourvellec    F  NaN
# 4  PHILIPPE          BIGOT          phmabigot    H  NaN
#
#    Situation Familliale   Profession                       Adresse   \
# 0                    NaN         NaN              10 place franklin
# 1                    NaN         NaN       23 Avenue Albert Laurens
# 2                    NaN         NaN     5 Allée Alexandre Vialatte
# 3                    NaN         NaN          16 Avenue de l'Alcyon
# 4                    NaN         NaN  8 Impasse du Chemin de Gesnes
#
#   Complement Adresse Code postal                     Ville            Région   \
# 0                NaN        68100                  Mulhouse         Grand-Est
# 1                NaN        34230            Saint-Pargoire         Occitanie
# 2        c/o Labadie        75013  Paris 13e Arrondissement     Île-de-France
# 3                NaN        44300                    Nantes  Pays-de-la-Loire
# 4                NaN        61000  Saint-Germain-du-Corbéis         Normandie
#
#   Pays   Nom d'utilisateur  Identifiant de la contrepartie  \
# 0    FR    romain-fontanel                        655971.0
# 1    FR       elodie-ramel                        655971.0
# 2    FR          melacafez                        656196.0
# 3    FR  elinalegourvellec                        655971.0
# 4    FR          phmabigot                        655971.0
#
#                      Courriel Numéro de téléphone  \
# 0  romain.fontanel@hotmail.fr        +33671350519
# 1    elodie.ramel@outlook.com       +330622676348
# 2          melacafez@yahoo.fr       +330622242230
# 3  elinalegourvellec@yahoo.fr        +33683876077
# 4          phmabigot@yahoo.fr       +330601843644
#
#         Titre de la contrepartie  Quantité  Montant unitaire total
# 0  Adhésion à vie - Tarif réduit       1.0                    39.0
# 1  Adhésion à vie - Tarif réduit       1.0                    39.0
# 2           ADHÉSION À VIE - Duo       1.0                    99.0
# 3  Adhésion à vie - Tarif réduit       1.0                    39.0
# 4  Adhésion à vie - Tarif réduit       1.0                    39.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1195 entries, 0 to 1194
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Prénom                          1157 non-null   object
#  1   Nom                             1157 non-null   object
#  2   Prénom - Nom                    1167 non-null   object
#  3   Sexe                            1154 non-null   object
#  4   Age                             0 non-null      float64
#  5   Situation Familliale            0 non-null      float64
#  6   Profession                      0 non-null      float64
#  7   Adresse                         1160 non-null   object
#  8   Complement Adresse              223 non-null    object
#  9   Code postal                     1160 non-null   object
#  10  Ville                           1160 non-null   object
#  11  Région                          866 non-null    object
#  12  Pays                            1185 non-null   object
#  13  Nom d'utilisateur               1167 non-null   object
#  14  Identifiant de la contrepartie  1156 non-null   float64
#  15  Courriel                        1167 non-null   object
#  16  Numéro de téléphone             1160 non-null   object
#  17  Titre de la contrepartie        1156 non-null   object
#  18  Quantité                        1167 non-null   float64
#  19  Montant unitaire total          1167 non-null   float64
# dtypes: float64(6), object(14)
# memory usage: 186.8+ KB

# %%
df['Titre de la contrepartie'].value_counts()
# Out:
# Adhésion à vie - Tarif réduit                 987
# ADHÉSION À VIE 🤩                               98
# ADHÉSION À VIE - Prix réduit                   36
# ADHÉSION À VIE - Duo                           18
# Adhésion à vie - Tarif normal                  12
# ADHÉSION À VIE - Share the love !               2
# ADHÉSION À VIE  À -35% 🥳 Prix de lancement      1
# ADHÉSION À VIE - Prix normal                    1
# ADHÉSION À VIE - Trio                           1
# Name: Titre de la contrepartie, dtype: int64

# %%
df.columns
# Out:
# Index(['Prénom ', 'Nom ', 'Prénom - Nom ', 'Sexe', 'Age',
#        'Situation Familliale ', 'Profession', 'Adresse ', 'Complement Adresse',
#        'Code postal ', 'Ville ', 'Région ', 'Pays ', 'Nom d'utilisateur',
#        'Identifiant de la contrepartie', 'Courriel', 'Numéro de téléphone',
#        'Titre de la contrepartie', 'Quantité', 'Montant unitaire total'],
#       dtype='object')

# %%
df['Ville '].value_counts()
# Out:
# Paris                       49
# Paris 11e Arrondissement    25
# Paris 18e Arrondissement    17
# Toulouse                    16
# Paris 12e Arrondissement    16
#                             ..
# Féternes                     1
# Ermont                       1
# Biarritz                     1
# Bagneux                      1
# Sète                         1
# Name: Ville , Length: 711, dtype: int64

# %%
df.Sexe.value_counts()
# Out:
# F    922
# H    232
# Name: Sexe, dtype: int64

# %%
round(df.isna().sum()/df.shape[0]*100, 2)
# Out:
# Prénom                              3.18
# Nom                                 3.18
# Prénom - Nom                        2.34
# Sexe                                3.43
# Age                               100.00
# Situation Familliale              100.00
# Profession                        100.00
# Adresse                             2.93
# Complement Adresse                 81.34
# Code postal                         2.93
# Ville                               2.93
# Région                             27.53
# Pays                                0.84
# Nom d'utilisateur                   2.34
# Identifiant de la contrepartie      3.26
# Courriel                            2.34
# Numéro de téléphone                 2.93
# Titre de la contrepartie            3.26
# Quantité                            2.34
# Montant unitaire total              2.34
# dtype: float64

# %%
df['Région '].value_counts().head(20)
# Out:
# Île-de-France                                                    299
# Auvergne-Rhône-Alpes                                             160
# Nouvelle-Aquitaine                                                64
# Occitanie                                                         62
# Provence-Alpes-Côte d'Azur                                        42
# Pays-de-la-Loire                                                  35
# Grand-Est                                                         34
# Bretagne                                                          22
# Centre-Val de Loire                                               19
# Hauts-de-France                                                   17
# Bourgogne-Franche-Comté                                           15
# Normandie                                                         14
# France                                                            10
# Région de Bruxelles-Capitale - Brussels Hoofdstedelijk Gewest      5
# FRANCE                                                             5
# Genève                                                             5
# Vaud                                                               4
# Paris                                                              3
# Haute-Savoie                                                       3
# Noord-Holland                                                      2
# Name: Région , dtype: int64

# %%
df.Quantité.value_counts()
# Out:
# 1.0    1131
# 2.0      24
# 3.0       8
# 4.0       2
# 5.0       2
# Name: Quantité, dtype: int64

# %%
df['Identifiant de la contrepartie'].value_counts()
# Out:
# 655971.0    987
# 669620.0     98
# 663095.0     36
# 656196.0     12
# 657937.0     12
# 669624.0      6
# 656199.0      2
# 663097.0      1
# 656197.0      1
# 656194.0      1
# Name: Identifiant de la contrepartie, dtype: int64

# %%
df['Titre de la contrepartie'].value_counts()
# Out:
# Adhésion à vie - Tarif réduit                 987
# ADHÉSION À VIE 🤩                               98
# ADHÉSION À VIE - Prix réduit                   36
# ADHÉSION À VIE - Duo                           18
# Adhésion à vie - Tarif normal                  12
# ADHÉSION À VIE - Share the love !               2
# ADHÉSION À VIE  À -35% 🥳 Prix de lancement      1
# ADHÉSION À VIE - Prix normal                    1
# ADHÉSION À VIE - Trio                           1
# Name: Titre de la contrepartie, dtype: int64

# %%
df['Code postal '].value_counts().head(20)
# Out:
# 75011    32
# 75018    27
# 75015    23
# 75017    21
# 07100    19
# 75013    17
# 75012    16
# 75020    12
# 75010    10
# 75019     9
# 07430     9
# 75009     9
# 75016     8
# 69002     8
# 69007     7
# 75007     7
# 44000     7
# 92500     6
# 75014     6
# 69003     6
# Name: Code postal , dtype: int64
